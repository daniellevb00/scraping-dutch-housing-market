# %% [markdown]
# # Scraping Huizenzoeker.nl to Analyse the Dutch Housing Market

# %% [markdown]
# Here we import both datasets in the form of CSV files from RStudio after they have been modified to work like real datasets (e.g. adjusting variable classes from character to numeric, and fixing the thousands/decimals delimiters).

# %%
#Import packages
import pandas as pd

# %% [markdown]
# **Municipality-level dataset**

# %%
huizenzoeker_municipality = pd.read_csv('huizenzoeker_municipality.csv', encoding= 'latin-1')

# %%
huizenzoeker_municipality = pd.DataFrame(huizenzoeker_municipality)
huizenzoeker_municipality
# Out:
#           province                 city  gem_vraagprijs  perc_ver_vraagprijs  \
# 0    Noord-Holland             Aalsmeer        685000.0                57.47
# 1    Noord-Holland              Alkmaar        362500.0                25.00
# 2    Noord-Holland           Amstelveen        570000.0                18.13
# 3    Noord-Holland            Amsterdam        450000.0                 7.78
# 4    Noord-Holland             Beemster        612000.0               -12.26
# ..             ...                  ...             ...                  ...
# 347        Limburg  ValkenburgaandeGeul        365000.0                -5.19
# 348        Limburg                Venlo        319000.0                16.00
# 349        Limburg               Venray        297000.0                 8.99
# 350        Limburg           Voerendaal        287500.0               -11.13
# 351        Limburg                Weert        350000.0                21.53
#
# ...

# %%
huizenzoeker_municipality.describe() #to return the summary statisitics for all municipalities in the Netherlands.
# Out:
#        gem_vraagprijs  perc_ver_vraagprijs  verk_woningen  perc_ver_verkocht  \
# count    3.520000e+02           341.000000     352.000000         346.000000
# mean     3.690349e+05             9.909560      18.127841         -22.113699
# std      1.549829e+05            28.825046      26.904773          52.621778
# min      0.000000e+00           -40.860000       0.000000        -100.000000
# 25%      2.950000e+05            -8.160000       6.000000         -52.222500
# 50%      3.500000e+05             4.520000      11.000000         -33.330000
# 75%      4.180000e+05            21.180000      19.250000          -3.965000
# max      1.695000e+06           149.630000     230.000000         325.000000
#
#        gem_m2prijs  perc_ver_m2prijs  perc_overboden  perc_ver_overboden  \
# count   352.000000        341.000000      348.000000          346.000000
# mean   3133.180614          3.972903       13.985144            4.637139
# ...

# %% [markdown]
# **Province-level dataset**

# %%
huizenzoeker_province = pd.read_csv('huizenzoeker_province.csv', encoding= 'latin-1')

# %%
huizenzoeker_province = pd.DataFrame(huizenzoeker_province)
huizenzoeker_province
# Out:
#          Province  gem_vraagprijs  perc_ver_vraagprijs  verk_woningen  \
# 0   Noord-Holland        425000.0                13.33            976
# 1    Zuid-Holland        365000.0                 7.67           1283
# 2         Zeeland        280000.0                 1.82            168
# 3   Noord-Brabant        350000.0                 3.24            739
# 4         Utrecht        425000.0                 9.25            608
# 5       Flevoland        339000.0                 4.31            153
# 6       Friesland        285000.0                 3.64            322
# 7       Groningen        250000.0                11.11            316
# 8         Drenthe        309000.0                 4.75            236
# 9      Overijssel        300000.0                 1.69            457
# 10     Gelderland        350000.0                 4.48            748
# 11        Limburg        285000.0                 3.64            376
#
# ...

# %%
huizenzoeker_province.describe()
# Out:
#        gem_vraagprijs  perc_ver_vraagprijs  verk_woningen  perc_ver_verkocht  \
# count       12.000000            12.000000      12.000000          12.000000
# mean    330250.000000             5.744167     531.833333         -27.470833
# std      55959.603936             3.740944     349.140199          13.309697
# min     250000.000000             1.690000     153.000000         -46.760000
# 25%     285000.000000             3.540000     296.000000         -38.332500
# 50%     324000.000000             4.395000     416.500000         -28.555000
# 75%     353750.000000             8.065000     741.250000         -15.297500
# max     425000.000000            13.330000    1283.000000          -8.300000
#
#        gem_m2prijs  perc_ver_m2prijs  perc_overboden  perc_ver_overboden  \
# count    12.000000         12.000000       12.000000           12.000000
# mean   3069.583333          4.158333       17.365000            6.389167
# ...

# %% [markdown]
# **Streets-level dataset**

# %%
huizenzoeker_streets = pd.read_csv('huizenzoeker_streets.csv', encoding= 'latin-1')

# %%
huizenzoeker_streets = pd.DataFrame(huizenzoeker_streets)
huizenzoeker_streets
# Out:
#                       straat woonplaats  n_woningen  gem_bouwjaar  \
# 0     VanMusschenbroekstraat    Tilburg          27          1972
# 1    VanOldenbarneveltstraat    Tilburg          32          1957
# 2         VanOosterzeestraat    Tilburg          43          1978
# 3          VanOtterloostraat    Tilburg          26          2007
# 4    VanSassevanYsseltstraat    Tilburg          60          1968
# ..                       ...        ...         ...           ...
# 209         Zwammerdamstraat    Tilburg           6          2018
# 210            Zwartsluishof    Tilburg          41          2019
# 211            Zwartvenseweg    Tilburg         136          1970
# 212             Zwijsenplein    Tilburg           1          1900
# 213                     Zwin    Tilburg          12          1993
#
#      gem_woon_m2  bioscoop_m  treinstation_m  busstation_m  school_m  \
# 0             76        1007            1478           336       215
# ...

# %%
huizenzoeker_streets.describe()
# Out:
#        n_woningen  gem_bouwjaar   gem_woon_m2    bioscoop_m  treinstation_m  \
# count  214.000000    214.000000    214.000000    214.000000      214.000000
# mean    44.135514   1979.794393    342.056075   3492.345794     1576.602804
# std     48.535988     26.822049   1211.719124   2679.006408      967.286275
# min      1.000000   1900.000000     10.000000     95.000000      191.000000
# 25%     14.250000   1961.250000     94.000000   1252.250000      787.000000
# 50%     27.000000   1980.000000    121.500000   2663.000000     1424.000000
# 75%     54.000000   2005.500000    169.750000   5841.500000     2132.750000
# max    349.000000   2021.000000  14463.000000  10033.000000     5232.000000
#
#        busstation_m     school_m  kinderopvang_m  supermarkt_m  best_inkomen
# count    214.000000   214.000000      214.000000    214.000000    141.000000
# mean     281.948598   485.191589      249.523364    664.929907  23822.304965
# ...
